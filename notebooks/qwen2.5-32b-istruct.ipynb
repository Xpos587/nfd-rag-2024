# %%
import statistics
import time

from openai import OpenAI

client = OpenAI(
    base_url="http://149.143.16.148:16225/v1",
    api_key="dummy_key"  # Это значение не используется, но должно быть указано
)

# %%
# Список тестовых запросов
test_queries = [
    "Какие основные правила безопасности на железной дороге?",
    "Расскажи о структуре РЖД",
    "Какие льготы доступны сотрудникам РЖД?",
    "Опиши процесс обучения новых сотрудников в РЖД",
    "Какие инновационные проекты реализует РЖД?"
]

# Функция для отправки запроса и измерения времени
def test_query(query):
    start_time = time.time()

    response = client.chat.completions.create(
        model="Qwen/Qwen2.5-32B-Instruct",
        messages=[
            {"role": "system", "content": "Вы - ассистент РЖД, помогающий новым сотрудникам."},
            {"role": "user", "content": query}
        ],
        max_tokens=500  # Ограничиваем длину ответа для ускорения тестирования
    )

    end_time = time.time()
    elapsed_time = end_time - start_time

    return elapsed_time, response.choices[0].message.content

# Проведение тестов
results = []
for query in test_queries:
    print(f"Тестирование запроса: {query}")
    elapsed_time, response = test_query(query)
    results.append(elapsed_time)
    print(f"Время ответа: {elapsed_time:.2f} секунд")
    print(f"Ответ: {response}")  # Выводим первые 100 символов ответа
    print("-" * 50)

# Анализ результатов
avg_time = statistics.mean(results)
min_time = min(results)
max_time = max(results)

print(f"Среднее время ответа: {avg_time:.2f} секунд")
print(f"Минимальное время ответа: {min_time:.2f} секунд")
print(f"Максимальное время ответа: {max_time:.2f} секунд")
# Out:
# Тестирование запроса: Какие основные правила безопасности на железной дороге?
# Время ответа: 7.73 секунд
# Ответ: Безопасность на железной дороге - это критически важный аспект для всех сотрудников РЖД. Вот некоторые основные правила безопасности, которые необходимо соблюдать:
#
# 1. **Соблюдение Правил铁路安全**：所有员工必须熟悉并遵守铁路安全规则和规程。这些规则涵盖了从操作设备到处理紧急情况的所有内容。
#
# 2. **穿戴适当的工作服**：根据工作性质，员工需穿戴适当的工作服和安全装备，如安全帽、防护眼镜、耳罩和防护鞋等。
#
# 3. **禁止饮酒和使用药物**：在工作时间内，严禁饮酒或使用可能影响判断力和反应能力的药物。
#
# 4. **注意工作区域**：始终保持工作区域的整洁和有序，避免因杂乱无章的环境而导致的事故。
#
# 5. **遵守信号和标志**：严格遵守所有铁路信号和标志的指示，这些标志用于指示危险区域或需要特别注意的地方。
#
# 6. **定期检查设备**：定期检查和维护所有设备和工具，确保它们处于良好的工作状态，以防止因设备故障导致的事故。
#
# 7. **紧急应对计划**：熟悉并了解紧急情况下的应对计划和疏散路线。定期参加紧急应变训练和模拟演练。
#
# 8. **沟通与协作**：保持良好的沟通和协作，确保信息准确无误地传达给团队成员，这对于避免误解和事故至关重要。
#
# 严格遵守这些安全规定不仅是为了保护自己，也是为了保护同事和其他铁路用户的安全。
# --------------------------------------------------
# Тестирование запроса: Расскажи о структуре РЖД
# Время ответа: 11.01 секунд
# Ответ: Российские железные дороги (РЖД) - это крупнейшая транспортная компания в России и одна из крупнейших в мире. Структура РЖД состоит из нескольких ключевых частей:
#
# 1. **Административно-управленческий центр**: Это центральная управляющая структура, которая занимается стратегическим планированием, развитием и координацией всех процессов компании. Включает в себя различные департаменты и управления, такие как департамент финансов, управления персоналом, информационных технологий и другие.
#
# 2. **Дирекции и управления**: Основные функциональные блоки, которые отвечают за различные аспекты деятельности компании, такие как эксплуатация, строительство, безопасность, управление персоналом и т.д.
#
# 3. **Филиалы и территориальные организаций**: РЖД состоит из филиалов, которые покрывают различные регионы России. Каждый филиал отвечает за эксплуатацию и обслуживание железнодорожного транспорта в своем регионе. Также существуют специализированные организации, такие как "Российский железнодорожный пассажирский союз", "РЖД Логистика", "Российские Северные морские пути" и другие.
#
# 4. **Производственные структуры**: Включают в себя ремонтные депо, станции, депо локомотивов и вагонов, которые занимаются эксплуатацией, обслуживанием и ремонтом подвижного состава и инфраструктуры.
#
# 5. **Дочерние и зависимые общества**: РЖД имеет множество дочерних компаний, которые специализируются на различных направлениях деятельности, включая логистику, строительство, эксплуатацию морских портов, цифровые технологии и другие.
#
# Эта структура позволяет РЖД эффективно управлять своей большой сетью и обеспечивать высокое
# --------------------------------------------------
# Тестирование запроса: Какие льготы доступны сотрудникам РЖД?
# Время ответа: 10.94 секунд
# Ответ: Работники РЖД имеют доступ к различным льготам и преимуществам, которые могут варьироваться в зависимости от конкретной должности, отделения и локальных правил. Однако, здесь перечислены некоторые из общих льгот:
#
# 1. **Скидки на проезд**: Сотрудники РЖД и их семьи могут получить значительные скидки на проезд в поездах, включая дальнемагистральные, пригородные и электрички.
#
# 2. **Здравоохранение**: Сотрудники могут пользоваться медицинским обслуживанием в специализированных медицинских учреждениях РЖД. Это включает бесплатные профилактические осмотры и лечение.
#
# 3. **Пенсионное обеспечение**: Работники РЖД имеют право на пенсионное обеспечение, которое может быть выше, чем стандартное пенсионное обеспечение, в зависимости от стажа работы и категории сотрудника.
#
# 4. **Жилищные льготы**: Некоторые сотрудники могут иметь доступ к льготам по обеспечению жильем, особенно те, кто работает в удаленных или труднодоступных районах.
#
# 5. **Образовательные льготы**: Сотрудники и их дети могут пользоваться скидками на обучение в профессиональных лицеях, техникумах и вузах, имеющих соглашения с РЖД.
#
# 6. **Социальные программы**: Компания предлагает различные субсидии, программы поддержки и компенсации, которые могут включать материальную помощь в случае болезни или трудной жизненной ситуации.
#
# 7. **Премии и бонусы**: Существуют программы поощрения за хорошую работу, которые могут включать в себя денежные премии, дополнительные дни отпуска и другие награды.
#
# Для получения более точной информации о льготах, доступных в вашем конкретном случае, рекомендую обратиться к отделу кадров вашей организации или ознакомиться с локальными правил
# --------------------------------------------------
# Тестирование запроса: Опиши процесс обучения новых сотрудников в РЖД
# Время ответа: 10.95 секунд
# Ответ: Процесс обучения новых сотрудников в РЖД включает несколько этапов, которые направлены на подготовку персонала к выполнению своих профессиональных обязанностей. Вот основные этапы:
#
# 1. **Вводный инструктаж**: Начинается обучение с вводного инструктажа, который проводится в первые дни работы. Этот инструктаж знакомит новых сотрудников с основными правилами безопасности, организационной структурой компании, корпоративной культурой и требованиями к поведению на рабочем месте.
#
# 2. **Теоретическое обучение**: В зависимости от должности, новым сотрудникам может быть предложено пройти курс теоретического обучения. Это могут быть курсы по специальности, которые помогают ознакомиться с технологическими процессами, правилами и нормами, а также с использованием специализированного оборудования.
#
# 3. **Практическое обучение**: Теория обязательно дополняется практикой. Новые сотрудники проходят обучение на рабочем месте под руководством опытных коллег. Это помогает им лучше понять, как применить полученные знания на практике.
#
# 4. **Профессиональная сертификация**: Для многих профессий в РЖД обязательна профессиональная сертификация. Это включает в себя прохождение экзаменов и тестов, подтверждающих, что сотрудник освоил необходимые для работы знания и навыки.
#
# 5. **Контроль и поддержка**: В течение первых месяцев работы, новым сотрудникам оказывается постоянная поддержка и помощь. Это может включать индивидуальные консультации, дополнительное обучение по мере необходимости, а также регулярные проверки знаний и навыков.
#
# 6. **Корпоративное развитие**: В РЖД также проводятся тренинги и семинары для профессионального развития сотрудников. Это помогает им оставаться в курсе новых технологий, методик работы и улучшать свои навыки.
#
# Важно отметить, что процесс обучения адаптиру
# --------------------------------------------------
# Тестирование запроса: Какие инновационные проекты реализует РЖД?
# Время ответа: 10.97 секунд
# Ответ: Российские железные дороги активно внедряют различные инновационные проекты, направленные на повышение эффективности и безопасности перевозок, а также на улучшение качества услуг для пассажиров и грузоотправителей. Вот некоторые примеры:
#
# 1. **Цифровая трансформация инфраструктуры**: РЖД внедряет системы мониторинга и управления инфраструктурой на основе искусственного интеллекта и большого数据分析。这些系统能够实时监控铁路基础设施的状态，并预测潜在的问题。
#
# 2. **Бесконтактные технологии**: РЖД внедряет бесконтактные технологии для упрощения прохода пассажиров через железнодорожные вокзалы и посадки в поезда. Это включает в себя использование биометрических данных для идентификации пассажиров.
#
# 3. **Электрификация магистралей**: РЖД продолжает электрифицировать железнодорожные магистрали, что позволяет улучшить экологическую безопасность и уменьшить расходы на топливо.
#
# 4. **Современные локомотивы и вагоны**: Внедряются новые локомотивы и вагоны с повышенной эффективностью и комфортом, включая электрические и гибридные локомотивы, а также вагоны с улучшенной изоляцией и автоматизированными системами управления.
#
# 5. **Телеметрия и аналитика**: Использование телеметрии для сбора данных с поездов и анализ их для оптимизации маршрутов, повышения безопасности и снижения износа подвижного состава.
#
# 6. **Автоматизация и роботизация**: Внедрение автоматизированных систем для управления железнодорожным движением, а также роботов для технического обслуживания и очистки инфраструктуры.
#
# 7. **Виртуальная и дополн
# --------------------------------------------------
# Среднее время ответа: 10.32 секунд
# Минимальное время ответа: 7.73 секунд
# Максимальное время ответа: 11.01 секунд

# %%
from typing import Dict, List

from pydantic import BaseModel, ValidationError


# Определение Pydantic модели для структурированного вывода
class EmployeeBenefits(BaseModel):
    name: str
    position: str
    benefits: List[str]
    joining_date: str

# Имитация вызова модели Qwen-2.5 Instruct
def simulate_model_call(query: str) -> Dict:
    # В реальном сценарии здесь был бы вызов API модели
    time.sleep(1)  # Имитация задержки ответа
    return {
        'name': 'Иванов Иван',
        'position': 'Старший специалист',
        'benefits': ['Медицинская страховка', 'Транспортные льготы'],
        'joining_date': '2024-01-15',
        'reasoning': 'Сначала я определил, что запрос касается льгот сотрудника. '
                     'Затем я собрал информацию о типичных льготах в РЖД. '
                     'Наконец, я структурировал ответ согласно запрошенному формату.'
    }

# Тест на структурированный вывод и валидацию через Pydantic
def test_structured_output(query: str) -> Dict:
    response = simulate_model_call(query)
    try:
        validated_data = EmployeeBenefits(**response)
        print(f"Структурированный вывод успешно валидирован: {validated_data}")
        return response
    except ValidationError as e:
        print(f"Ошибка валидации: {e}")
        return {}

# Тест на Chain of Thought (CoT)
def test_chain_of_thought(query: str) -> bool:
    response = simulate_model_call(query)
    if 'reasoning' in response and len(response['reasoning'].split()) > 10:
        print(f"CoT присутствует: {response['reasoning']}")
        return True
    else:
        print("CoT отсутствует или недостаточно подробный")
        return False

# Чеклист для оценки качества ответа
def run_checklist(response: Dict) -> List[bool]:
    checklist = [
        lambda r: len(r['name']) > 0,
        lambda r: len(r['position']) > 0,
        lambda r: len(r['benefits']) > 0,
        lambda r: len(r['joining_date']) == 10,  # Формат даты YYYY-MM-DD
        lambda r: 'reasoning' in r and len(r['reasoning']) > 0
    ]
    return [check(response) for check in checklist]


query = "Какие льготы доступны сотрудникам РЖД?"

print("Тест 1: Структурированный вывод и Pydantic валидация")
structured_output = test_structured_output(query)

print("\nТест 2: Chain of Thought")
cot_present = test_chain_of_thought(query)

print("\nТест 3: Проверка по чеклисту")
checklist_results = run_checklist(structured_output)
print(f"Результаты чеклиста: {checklist_results}")

print("\nИтоговые результаты:")
print(f"Структурированный вывод: {'Успешно' if structured_output else 'Неуспешно'}")
print(f"Chain of Thought: {'Присутствует' if cot_present else 'Отсутствует'}")
print(f"Чеклист пройден: {all(checklist_results)}")
# Out:
# Тест 1: Структурированный вывод и Pydantic валидация
# Структурированный вывод успешно валидирован: name='Иванов Иван' position='Старший специалист' benefits=['Медицинская страховка', 'Транспортные льготы'] joining_date='2024-01-15'
#
# Тест 2: Chain of Thought
# CoT присутствует: Сначала я определил, что запрос касается льгот сотрудника. Затем я собрал информацию о типичных льготах в РЖД. Наконец, я структурировал ответ согласно запрошенному формату.
#
# Тест 3: Проверка по чеклисту
# Результаты чеклиста: [True, True, True, True, True]
#
# Итоговые результаты:
# Структурированный вывод: Успешно
# Chain of Thought: Присутствует
# Чеклист пройден: True
